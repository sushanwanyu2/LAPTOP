# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# 定义x的范围和数量
x=np.linspace(-3,3,100)
y=x**2

# %%
plt.figure(num=3,dpi=300,figsize=(8,5))

# %%
plt.plot(x,y,color='red',linewidth=1.0,linestyle='--') # 设置线宽和线型颜色等
plt.show()
